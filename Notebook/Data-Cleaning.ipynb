# %% [markdown]
# ### 1. Importing Librabries

# %%
import os

import numpy as np

import pandas as pd

from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 2. Reading the Data

# %%
PROJECT_DIR = r"C:\Users\harsh\OneDrive\Desktop\Flight-Price-Prediction"
DATA_DIR = 'data'

# %%
def read_data(name):
    file_name = f"{name}.csv"
    file_path = os.path.join(PROJECT_DIR,DATA_DIR,file_name)
    return pd.read_csv(file_path)

# %%
flights = read_data("flight_price")

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# - The dataset contains 10,683 rows and 11 features
# - Columns 'Route' and 'Total_Stops' have missing value each
# - The data types of some features isn't approriate

# %% [markdown]
# ### 3. Preliminary Analysis

# %% [markdown]
# ### 3.1 Check Data Types

# %%
flights.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24-03-2019  Banglore   New Delhi              BLR → DEL
# 1    Air India      01-05-2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      09-06-2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12-05-2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01-03-2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time      Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  22-03-2024 01:10   2h 50m    non-stop         No info   3897
# 1    05:50             13:15   7h 25m     2 stops         No info   7662
# 2    09:25  10-06-2024 04:25      19h     2 stops         No info  13882
# 3    18:05             23:30   5h 25m      1 stop         No info   6218
# 4    16:50             21:35   4h 45m      1 stop         No info  13302

# %%
flights.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# ### 3.2 Check for Duplicates

# %%
(
    flights
    .loc[flights.duplicated(keep = False)]
    .sort_values(['Airline','Date_of_Journey','Source','Destination'])
    
)
# Out:
#         Airline Date_of_Journey    Source Destination                  Route  \
# 6321  Air India      01-03-2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 9848  Air India      01-03-2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 1495  Air India      01-04-2019   Kolkata    Banglore  CCU → DEL → COK → BLR
# 9913  Air India      01-04-2019   Kolkata    Banglore  CCU → DEL → COK → BLR
# 3598  Air India      01-05-2019   Kolkata    Banglore  CCU → GAU → DEL → BLR
# ...         ...             ...       ...         ...                    ...
# 2692   SpiceJet      24-03-2019  Banglore   New Delhi              BLR → DEL
# 2870   SpiceJet      24-03-2019  Banglore   New Delhi              BLR → DEL
# 3711   SpiceJet      24-03-2019  Banglore   New Delhi              BLR → DEL
# 2634    Vistara      24-03-2019  Banglore   New Delhi              BLR → DEL
# 5470    Vistara      24-03-2019  Banglore   New Delhi              BLR → DEL
#
#      Dep_Time      Arrival_Time Duration Total_Stops  \
# 6321    08:50  02-03-2024 23:55   39h 5m     2 stops
# 9848    08:50  02-03-2024 23:55   39h 5m     2 stops
# 1495    10:00  02-04-2024 01:20  15h 20m     2 stops
# 9913    10:00  02-04-2024 01:20  15h 20m     2 stops
# 3598    09:50  02-05-2024 08:55   23h 5m     2 stops
# ...       ...               ...      ...         ...
# 2692    05:45             08:35   2h 50m    non-stop
# 2870    05:45             08:35   2h 50m    non-stop
# 3711    20:30             23:20   2h 50m    non-stop
# 2634    11:30             14:10   2h 40m    non-stop
# 5470    11:30             14:10   2h 40m    non-stop
#
#                    Additional_Info  Price
# 6321                       No info  17135
# 9848                       No info  17135
# 1495                       No info  10408
# 9913                       No info  10408
# 3598                       No info  13227
# ...                            ...    ...
# 2692  No check-in baggage included   4273
# 2870  No check-in baggage included   4273
# 3711  No check-in baggage included   3873
# 2634                       No info   5403
# 5470                       No info   5403
#
# [415 rows x 11 columns]

# %% [markdown]
# ### 3.3 Observations

# %% [markdown]
# - The type of 'Date_of_Journey', 'Dep_Time' and 'Arrival_Time' should be changed to datetime
# - The type of 'Duration' and 'Total_stops' is mixed. It should be numeric type
# - There are 220 duplicates. These should be removed

# %% [markdown]
# ### 4, Detailed Analysis

# %% [markdown]
# ## Airline

# %%
flights.Airline.unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
flights.Airline.str.replace('Premium economy','')
# Out:
# 0             IndiGo
# 1          Air India
# 2        Jet Airways
# 3             IndiGo
# 4             IndiGo
#             ...
# 10678       Air Asia
# 10679      Air India
# 10680    Jet Airways
# 10681        Vistara
# 10682      Air India
# Name: Airline, Length: 10683, dtype: object

# %%
(
    flights
    .Airline
    .str.replace('Premium economy','')
    .str.replace('Business','')
    .str.title()
    .unique()
)
# Out:
# array(['Indigo', 'Air India', 'Jet Airways', 'Spicejet',
#        'Multiple Carriers', 'Goair', 'Vistara', 'Air Asia', 'Vistara ',
#        'Jet Airways ', 'Multiple Carriers ', 'Trujet'], dtype=object)

# %% [markdown]
# - Some of the entries have inconsistent/inaccurate values

# %% [markdown]
# ## Date of Journey

# %%
pd.to_datetime(flights.Date_of_Journey,dayfirst = True)
# Out:
# 0       2019-03-24
# 1       2019-05-01
# 2       2019-06-09
# 3       2019-05-12
# 4       2019-03-01
#            ...
# 10678   2019-04-09
# 10679   2019-04-27
# 10680   2019-04-27
# 10681   2019-03-01
# 10682   2019-05-09
# Name: Date_of_Journey, Length: 10683, dtype: datetime64[ns]

# %% [markdown]
# ## Source

# %%
flights.Source.unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %% [markdown]
# ### Destination

# %%
flights.Destination.unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %% [markdown]
# ### Dep_time

# %%
(
    flights
    .Dep_Time
    .loc[lambda ser : ser.str.contains("[^0-9:]")]
)
# Out:
# Series([], Name: Dep_Time, dtype: object)

# %%
pd.to_datetime(flights.Dep_Time).dt.time
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_65664\1056054517.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(flights.Dep_Time).dt.time
# 0        22:20:00
# 1        05:50:00
# 2        09:25:00
# 3        18:05:00
# 4        16:50:00
#            ...
# 10678    19:55:00
# 10679    20:45:00
# 10680    08:20:00
# 10681    11:30:00
# 10682    10:55:00
# Name: Dep_Time, Length: 10683, dtype: object

# %%
(
    flights
    .Arrival_Time
    .loc[lambda ser : ser.str.contains("[^0-9:]")]
    .str.split(" ")
    .str.get(1)
    .unique()
)
# Out:
# array(['01:10', '04:25', '10:25', '05:05', '09:20', '19:15', '12:35',
#        '13:20', '08:15', '03:35', '19:00', '11:05', '10:55', '00:15',
#        '02:45', '12:00', '01:30', '16:45', '09:25', '04:40', '11:25',
#        '14:25', '14:35', '09:05', '01:35', '10:05', '11:10', '07:45',
#        '00:55', '23:35', '00:40', '18:50', '07:55', '18:15', '13:15',
#        '09:45', '06:50', '15:15', '07:40', '02:20', '18:30', '19:45',
#        '19:50', '01:00', '00:05', '16:20', '00:30', '00:50', '13:45',
#        '09:15', '07:10', '08:55', '04:45', '05:35', '09:00', '10:45',
#        '22:10', '22:40', '05:25', '02:15', '20:20', '06:35', '01:20',
#        '19:10', '10:50', '23:25', '12:15', '10:40', '23:15', '22:55',
#        '09:10', '18:10', '00:25', '20:45', '21:05', '23:00', '00:45',
#        '04:35', '18:00', '12:30', '02:10', '00:20', '23:20', '12:25',
#        '22:35', '20:25', '00:35', '16:50', '09:30', '12:05', '10:35',
#        '15:05', '18:40', '09:35', '08:50', '16:40', '19:40', '16:10',
#        '21:20', '07:25', '20:40', '13:00', '11:20', '00:10', '08:10',
#        '16:15', '22:05', '10:00', '18:05', '10:30', '18:20', '01:45',
#        '16:30', '11:55', '09:50', '13:40', '10:15', '15:20', '18:25',
#        '19:25', '23:55', '17:20', '03:40', '13:55', '19:55', '18:45',
#        '11:35', '08:45'], dtype=object)

# %%
(
    flights
    .Arrival_Time
    .loc[lambda ser: ser.str.contains("[^0-9:]")]
    .str.split(" ")
    .str.get(1),
    pd.to_datetime(flights.Arrival_Time,format='mixed').dt.time
)
# Out:
# (0        01:10
#  2        04:25
#  6        10:25
#  7        05:05
#  8        10:25
#           ...
#  10666    19:00
#  10667    20:20
#  10672    19:00
#  10673    04:25
#  10674    21:20
#  Name: Arrival_Time, Length: 4335, dtype: object,
#  0        01:10:00
#  1        13:15:00
#  2        04:25:00
#  3        23:30:00
#  4        21:35:00
#             ...
#  10678    22:25:00
#  10679    23:20:00
#  10680    11:20:00
#  10681    14:10:00
#  10682    19:15:00
#  Name: Arrival_Time, Length: 10683, dtype: object)

# %%
flights
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24-03-2019  Banglore   New Delhi
# 1        Air India      01-05-2019   Kolkata    Banglore
# 2      Jet Airways      09-06-2019     Delhi      Cochin
# 3           IndiGo      12-05-2019   Kolkata    Banglore
# 4           IndiGo      01-03-2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      09-04-2019   Kolkata    Banglore
# 10679    Air India      27-04-2019   Kolkata    Banglore
# 10680  Jet Airways      27-04-2019  Banglore       Delhi
# 10681      Vistara      01-03-2019  Banglore   New Delhi
# 10682    Air India      09-05-2019     Delhi      Cochin
#
#                        Route Dep_Time      Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  22-03-2024 01:10   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50             13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  10-06-2024 04:25      19h     2 stops
# 3            CCU → NAG → BLR    18:05             23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50             21:35   4h 45m      1 stop
# ...                      ...      ...               ...      ...         ...
# 10678              CCU → BLR    19:55             22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45             23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20             11:20       3h    non-stop
# 10681              BLR → DEL    11:30             14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55             19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# ## Duration

# %%
(
    flights
    .Duration
    .loc[lambda ser: ~ser.str.contains('h')]
    #.str.split(n = 1,expand = True)
    #.set_axis(['hour','minute'],axis = 'columns')
    
    
    #.isna().sum()
)
# Out:
# 6474    5m
# Name: Duration, dtype: object

# %%
(
    flights
    .Duration
    .drop(index = [6474])
    .str.split(expand = True)
    .set_axis(['hour','minute'],axis = 1)
    .assign(

        hour = lambda df_: (

            df_
            .hour.str.replace('h','')
            .astype(int)
            .mul(60)
        ),
        minute = lambda df_ : (

            df_
            .minute.str.replace('m','')
            .fillna('0')
            .astype(int)
            
        )
    )
    .sum(axis = 1)
    .rename('duration_minutes')
    .to_frame()
)
# Out:
#        duration_minutes
# 0                   170
# 1                   445
# 2                  1140
# 3                   325
# 4                   285
# ...                 ...
# 10678               150
# 10679               155
# 10680               180
# 10681               160
# 10682               500
#
# [10682 rows x 1 columns]

# %%
flights.iloc[6474]
# Out:
# Airline                        Air India
# Date_of_Journey               06-03-2019
# Source                            Mumbai
# Destination                    Hyderabad
# Route              BOM → GOI → PNQ → HYD
# Dep_Time                           16:50
# Arrival_Time                       16:55
# Duration                              5m
# Total_Stops                      2 stops
# Additional_Info                  No info
# Price                              17327
# Name: 6474, dtype: object

# %% [markdown]
# ## Total Stops

# %%
flights.Total_Stops.isna().sum()
# Out:
# 1

# %%
(
    flights
    .Total_Stops
    .replace('non-stop','0')
    .str.replace('stops?','',regex = True)
    .pipe(lambda ser : pd.to_numeric(ser))
)
# Out:
# 0        0.0
# 1        2.0
# 2        2.0
# 3        1.0
# 4        1.0
#         ...
# 10678    0.0
# 10679    0.0
# 10680    0.0
# 10681    0.0
# 10682    2.0
# Name: Total_Stops, Length: 10683, dtype: float64

# %% [markdown]
# ### 5. Cleaning Operations

# %%
def convert_to_minutes(ser):
    return (

        ser
        .str.split(expand = True)
        .set_axis(['hour','minute'],axis = 1)
        .assign(

                  hour = lambda df_: (

            df_
            .hour.str.replace('h','')
            .astype(int)
            .mul(60)
        ),
        minute = lambda df_ : (

            df_
            .minute.str.replace('m','')
            .fillna('0')
            .astype(int)
            
        )
    )
    .sum(axis = 1)

        
    )

# %%
def clean_data(df):
    return (
        df
        .drop(index = [6474])
        .drop_duplicates()
        .assign(**{
             col : df[col].str.strip()
            for col in df.select_dtypes(include = 'O').columns           
        })
        
        .rename(columns = str.lower)

        .assign(

            airline = lambda df_: (

                df_
                .airline
                .str.replace('Premium economy','')
                .str.replace('Business','')
                .str.title()
            ),
            date_of_journey = lambda df_ : pd.to_datetime(df_.date_of_journey,dayfirst = True),
            dep_time = lambda df_ : pd.to_datetime(df_.dep_time).dt.time,
            arrival_time = lambda df_ : pd.to_datetime(df_.arrival_time,format = 'mixed').dt.time,
            duration = lambda df_ : df_.duration.pipe(convert_to_minutes),
            total_stops = lambda df_ : (

                df_
                .total_stops
                .replace('non-stop','0')
                .str.replace('stops?','',regex = True)
                .pipe(lambda ser : pd.to_numeric(ser))
            )
        )
        .drop('route',axis = 1)
    
    
    
    
    )

# %%
import warnings
warnings.filterwarnings('ignore')
flights_cleaned = clean_data(flights)
flights_cleaned
# Out:
#            airline date_of_journey    source destination  dep_time  \
# 0           Indigo      2019-03-24  Banglore   New Delhi  22:20:00
# 1        Air India      2019-05-01   Kolkata    Banglore  05:50:00
# 2      Jet Airways      2019-06-09     Delhi      Cochin  09:25:00
# 3           Indigo      2019-05-12   Kolkata    Banglore  18:05:00
# 4           Indigo      2019-03-01  Banglore   New Delhi  16:50:00
# ...            ...             ...       ...         ...       ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore  19:55:00
# 10679    Air India      2019-04-27   Kolkata    Banglore  20:45:00
# 10680  Jet Airways      2019-04-27  Banglore       Delhi  08:20:00
# 10681      Vistara      2019-03-01  Banglore   New Delhi  11:30:00
# 10682    Air India      2019-05-09     Delhi      Cochin  10:55:00
#
#       arrival_time  duration  total_stops additional_info  price
# 0         01:10:00       170          0.0         No info   3897
# 1         13:15:00       445          2.0         No info   7662
# 2         04:25:00      1140          2.0         No info  13882
# 3         23:30:00       325          1.0         No info   6218
# 4         21:35:00       285          1.0         No info  13302
# ...            ...       ...          ...             ...    ...
# 10678     22:25:00       150          0.0         No info   4107
# 10679     23:20:00       155          0.0         No info   4145
# 10680     11:20:00       180          0.0         No info   7229
# 10681     14:10:00       160          0.0         No info  12648
# 10682     19:15:00       500          2.0         No info  11753
#
# [10462 rows x 10 columns]

# %% [markdown]
# ### 6. Split the Data

# %%
flights_final = flights_cleaned.sample(1000)

# %%
X = flights_final.drop('price',axis = 1)
Y = flights_final.price.copy()

# %%
X_,X_test,Y_,Y_test = train_test_split(X,Y,test_size = 0.2,random_state = 42)
X_train,X_val,Y_train,Y_val = train_test_split(X_,Y_,test_size = 0.2,random_state = 42)

print(X_train.shape,Y_train.shape)
print(X_val.shape,Y_val.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (640, 9) (640,)
# (160, 9) (160,)
# (200, 9) (200,)

# %% [markdown]
# ### 7. Export the Subset

# %%
def export_data(X,Y,name):
    file_name = f"{name}.csv"
    file_path = os.path.join(PROJECT_DIR,DATA_DIR,file_name)
    X.join(Y).to_csv(file_path,index = False)
    return pd.read_csv(file_path).head()

# %%
export_data(X_train,Y_train,'train')
# Out:
#        airline date_of_journey    source destination  dep_time arrival_time  \
# 0  Jet Airways      2019-06-12   Kolkata    Banglore  18:55:00     18:15:00
# 1       Indigo      2019-03-18    Mumbai   Hyderabad  06:20:00     07:45:00
# 2  Jet Airways      2019-06-09   Kolkata    Banglore  09:35:00     22:05:00
# 3  Jet Airways      2019-06-06   Kolkata    Banglore  20:25:00     09:45:00
# 4       Indigo      2019-03-24  Banglore   New Delhi  08:30:00     11:30:00
#
#    duration  total_stops              additional_info  price
# 0      1400          1.0  In-flight meal not included   8529
# 1        85          0.0                      No info   3342
# 2       750          1.0  In-flight meal not included  13994
# 3       800          1.0  In-flight meal not included  10539
# 4       180          0.0                      No info   7303

# %%
export_data(X_val,Y_val,'val')
# Out:
#              airline date_of_journey    source destination  dep_time  \
# 0          Air India      2019-04-24  Banglore       Delhi  21:05:00
# 1           Spicejet      2019-06-06     Delhi      Cochin  17:55:00
# 2  Multiple Carriers      2019-06-15     Delhi      Cochin  11:30:00
# 3        Jet Airways      2019-05-27     Delhi      Cochin  14:00:00
# 4             Indigo      2019-05-21     Delhi      Cochin  06:40:00
#
#   arrival_time  duration  total_stops              additional_info  price
# 0     23:55:00       170          0.0                      No info   5228
# 1     22:50:00       295          1.0                      No info   5409
# 2     21:00:00       570          1.0                      No info  13587
# 3     04:25:00       865          1.0  In-flight meal not included  12898
# 4     21:00:00       860          1.0                      No info   7006

# %%
export_data(X_test,Y_test,'test')
# Out:
#        airline date_of_journey    source destination  dep_time arrival_time  \
# 0       Indigo      2019-05-18     Delhi      Cochin  08:35:00     22:30:00
# 1     Spicejet      2019-06-21    Mumbai   Hyderabad  22:45:00     00:15:00
# 2     Spicejet      2019-03-15    Mumbai   Hyderabad  13:10:00     14:30:00
# 3  Jet Airways      2019-06-27     Delhi      Cochin  19:30:00     12:35:00
# 4     Spicejet      2019-05-21  Banglore       Delhi  05:55:00     08:35:00
#
#    duration  total_stops               additional_info  price
# 0       835          1.0                       No info   7144
# 1        90          0.0                       No info   2017
# 2        80          0.0  No check-in baggage included   2385
# 3      1025          2.0                       No info  13764
# 4       160          0.0                       No info   3311
